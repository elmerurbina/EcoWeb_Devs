# %% [markdown]
# # Manual de Uso de VerdeNica
#
# ## Descripción
# VerdeNica es un proyecto innovador diseñado para promover las buenas prácticas con el medio ambiente con un enfoque comunitario, permitiendo a los y las nicaragüenses participar activamente en la creación de campañas ambientales, documentar cualquier dato relacionado a la flora, fauna o medio ambiente en general a través de publicaciones, y denunciar violaciones ambientales de forma anónima, garantizando la integridad del usuario y del contenido que se publica en la plataforma.
#
# ## Requisitos Previos
# Para utilizar la plataforma solo necesitas un teléfono móvil, tablet o computadora con conexión a internet. Accede a la URL del sitio en tu navegador web favorito o mediante un sistema de búsqueda como Google o Edge.
#
# ## Principales Interfaces y sus Funciones
#
# ### Inicio
# - La pantalla principal muestra un encabezado verde con el slogan de la plataforma.
# - Un menú horizontal celeste contiene cinco elementos: **Empresas Sostenibles**, **Campañas**, **Foro**, **Ayuda**.
# - La sección **main** incluye:
#   - Botones para acceder al Acuerdo de París y al compendio de leyes de Nicaragua en formato PDF.
#   - Botón de **Denuncias** que lleva a la página de denuncias existentes y para crear nuevas denuncias.
#
# ![Captura de Pantalla - Página de Inicio](../static/imagenes/inicio-uno.png)
#
#   - Botones para **Crear Nueva Publicación**, **Biodiversidad en Nicaragua**, y **Reconocimiento de Especies con IA**.
#   - Listas de causas y consecuencias del cambio climático.
#   - Información sobre **Mitigación** y **Adaptación**.
#   - Sección sobre **Sostenibilidad** con un enlace a una página dedicada.
#   - **Acciones de Mitigación** que son enlaces a detalles sobre acciones aplicables en la vida diaria.
#
# **Captura de Pantalla de la Página de Inicio:**
# ![Captura de Pantalla - Página de Inicio](../static/imagenes/inicio-dos.png)
#
#
# ### Cómo Funciona la Suscripción por Correo
# El usuario ingresa su email y hace clic en **Suscribirse**. Este formulario utiliza **Formspree** para enviar un correo notificando que un usuario ha enviado el formulario junto con su dirección de correo electrónico.
#
# **Captura de Pantalla del Formulario de Suscripción por Correo:**
#
# ![Captura de Pantalla - Suscripción por Correo](../static/imagenes/suscripciones.png)
#
# ### Footer
# La parte inferior contiene información básica sobre nosotros, incluyendo la Misión, Visión y Valores de la plataforma.
#
# **Captura de Pantalla del Footer:**
#
# ![Captura de Pantalla - Footer](../static/imagenes/footer.png)
#
# ### Empresas Sostenibles
# Apartado dedicado a la venta de servicios y productos para empresas con un enfoque en la sostenibilidad, incluyendo talleres y acceso a material didáctico exclusivo.
#
# **Captura de Pantalla de la Página de Empresas Sostenibles:**
#
# ![Captura de Pantalla - Empresas Sostenibles](../static/imagenes/empresas_sostenibles.png)
#
# ### Campañas
# Aquí puedes ver todas las campañas creadas por los usuarios. Puedes dar **like** o **dislike** y crear una nueva campaña al iniciar sesión.
#
# **Captura de Pantalla de la Página de Campañas:**
#
# ![Captura de Pantalla - Campañas](../static/imagenes/campania.png)
#
# ### Foro
# Espacio para compartir ideas sobre el medio ambiente, organizado en categorías: **Pregunta**, **Debate**, **Hilo de Conversación**. Necesitas iniciar sesión para publicar o responder contenido.
#
# **Captura de Pantalla de la Página del Foro:**
#
# ![Captura de Pantalla - Foro](../static/imagenes/foro.png)
#
# ### Ayuda
# Contiene información de contacto y una lista de preguntas frecuentes para asistencia técnica.
#
# **Captura de Pantalla de la Página de Ayuda:**
#
# ![Captura de Pantalla - Ayuda](../static/imagenes/ayuda.png)
#
# ### Biodiversidad en Nicaragua
# Dedicado a la flora y fauna del país con imágenes, nombres y descripciones breves sobre cada especie.
#
# **Captura de Pantalla de la Página de Biodiversidad:**
#
# ![Captura de Pantalla - Biodiversidad](../static/imagenes/biodiversidad.png)
#
# ### Nueva Publicación
# Formulario para crear una nueva publicación sobre flora, fauna o medio ambiente. Las publicaciones pueden recibir **like** o **dislike**.
#
# **Captura de Pantalla del Formulario de Nueva Publicación:**
#
# ![Captura de Pantalla - Nueva Publicación](../static/imagenes/nueva_publicacion.png)
#
# ### Reconocimiento de Especies con IA
# Entrenado para reconocer especies de animales o plantas mediante IA. Puedes subir imágenes y recibir información sobre la especie.
#
# **Captura de Pantalla de la Página de Reconocimiento de Especies:**
#
# ![Captura de Pantalla - Reconocimiento de Especies](../static/imagenes/reconocimiento_ia.png)
#
# ### Sistema de Autenticación
# Requerido para los usuarios que desean interactuar en el foro o en el apartado de campañas. Incluye inicio de sesión y recuperación de credenciales.
#
# **Captura de Pantalla del Sistema de Autenticación:**
#
# ![Captura de Pantalla - Autenticación](../static/imagenes/autenticacion.png)
